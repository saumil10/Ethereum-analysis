# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/home/jovyan/teaching_material/ECS765P/cousework/PART A/numtxn.csv')

# %%
df1.columns = ['Date', 'Total Transactions each month']

# %%
df1.head()
# Out:
#           Date  Total Transactions each month
# 0  ["01/2017"]                        1409664
# 1  ["01/2018"]                       33504270
# 2  ["01/2019"]                        1002431
# 3  ["02/2016"]                         520040
# 4  ["02/2017"]                        1410048

# %%
# remove brackets and comma from the 'Date' column
df1['Date'] = df1['Date'].str.replace('[^\w\s]', '').str.strip()

# convert the 'Date' column to datetime format
df1['Date'] = pd.to_datetime(df1['Date'], format='%m%Y')

# print the resulting DataFrame
print(df1)
# Out:
#          Date  Total Transactions each month
# 0  2017-01-01                        1409664
# 1  2018-01-01                       33504270
# 2  2019-01-01                        1002431
# 3  2016-02-01                         520040
# 4  2017-02-01                        1410048
# 5  2018-02-01                       22231978
# 6  2016-03-01                         917170
# 7  2017-03-01                        2426471
# 8  2018-03-01                       20261862
# 9  2016-04-01                        1023096
# 10 2017-04-01                        2539966
# 11 2018-04-01                       20876642
# 12 2016-05-01                        1346796
# 13 2017-05-01                        4245516
# 14 2018-05-01                       25105717
# 15 2016-06-01                        1351536
# 16 2017-06-01                        7244657
# 17 2018-06-01                       22471788
# 18 2016-07-01                        1356907
# 19 2017-07-01                        7835875
# ...

# %%
plt.figure(figsize = (20,10))
plt.xticks(rotation=90)
plt.xlabel('Month/Year')
plt.ylabel('Total Transactions each month')
x=df1['Date']
y=df1['Total Transactions each month']
plt.bar(x,y,color='purple', width=30)
# Out:
# <BarContainer object of 41 artists>

# %%
df1['Total Transactions each month']
# Out:
# 0      1409664
# 1     33504270
# 2      1002431
# 3       520040
# 4      1410048
# 5     22231978
# 6       917170
# 7      2426471
# 8     20261862
# 9      1023096
# 10     2539966
# 11    20876642
# 12     1346796
# 13     4245516
# 14    25105717
# 15     1351536
# 16     7244657
# 17    22471788
# 18     1356907
# 19     7835875
# 20    19937033
# 21       85609
# 22     1405743
# 23    10523178
# 24    19842059
# 25      173805
# 26     1387412
# 27    10679242
# 28    16056742
# 29      205045
# 30     1329847
# 31    12602063
# 32    17056926
# 33      234733
# 34     1301586
# 35    15292269
# 36    16713911
# 37      347092
# 38     1316131
# 39    26732085
# 40    17107601
# Name: Total Transactions each month, dtype: int64
